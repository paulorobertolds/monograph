# %% [markdown]
# <a href="https://colab.research.google.com/github/paulorobertolds/monograph/blob/main/Setor_de_Servi%C3%A7os.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing required packages
import pandas as pd
import numpy as np

#importing the data
df = pd.read_csv('https://raw.githubusercontent.com/paulorobertolds/monograph/main/zaninData.csv' )


print(df.shape)
df.head()
# Out:
# (21662, 22)
#   Data de extração         Base de dados SETOR IBGE            Tipo   Ano  \
# 0        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 1        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 2        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 3        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 4        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
#
#     Local Seção                                       Seção (Nome)  Divisão  \
# 0  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 1  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 2  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 3  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 4  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
#
# ...

# %%
df=df.drop(df.columns[[17,18,19,20,21]],axis =1)
df.head()
# Out:
#   Data de extração         Base de dados SETOR IBGE            Tipo   Ano  \
# 0        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 1        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 2        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 3        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
# 4        12/8/2021  RAIS ESTABELECIMENTO        PAS  N° de empresas  2009
#
#     Local Seção                                       Seção (Nome)  Divisão  \
# 0  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 1  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 2  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 3  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
# 4  Cuiabá     A  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...        1
#
#                                   Divisão (Nome)  Grupo  \
# ...

# %%
np.unique(df[df.columns[[6]]])
# Out:
# array(['A', 'C', 'E', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'P', 'R',
#        'S'], dtype=object)

# %%
np.unique(df[df.columns[[7]]])
# Out:
# array(['AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA',
#        'ALOJAMENTO E ALIMENTAÇÃO', 'ARTES, CULTURA, ESPORTE E RECREAÇÃO',
#        'ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMENTARES',
#        'ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS RELACIONADOS',
#        'ATIVIDADES IMOBILIÁRIAS',
#        'ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS',
#        'COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E MOTOCICLETAS',
#        'EDUCAÇÃO', 'INDÚSTRIAS DE TRANSFORMAÇÃO',
#        'INFORMAÇÃO E COMUNICAÇÃO', 'OUTRAS ATIVIDADES DE SERVIÇOS',
#        'TRANSPORTE, ARMAZENAGEM E CORREIO',
#        'ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS E DESCONTAMINAÇÃO'],
#       dtype=object)

# %%
# Nomes das colunas
print(df.columns.values)
# Out:
# ['Data de extração' 'Base de dados' 'SETOR IBGE' 'Tipo' 'Ano' 'Local'
#  'Seção' 'Seção (Nome)' 'Divisão' 'Divisão (Nome)' 'Grupo' 'Grupo (Nome)'
#  'Classe' 'Classe (Nome)' 'Subclasse' 'Denominação' 'Total']

# %%
# Remover colunas desnecessárias:
df=df.drop(['Data de extração','Base de dados','SETOR IBGE','Divisão','Divisão (Nome)','Grupo','Grupo (Nome)','Classe','Classe (Nome)','Subclasse','Denominação'],axis=1)
df.head()
# Out:
#              Tipo   Ano   Local Seção  \
# 0  N° de empresas  2009  Cuiabá     A
# 1  N° de empresas  2009  Cuiabá     A
# 2  N° de empresas  2009  Cuiabá     A
# 3  N° de empresas  2009  Cuiabá     A
# 4  N° de empresas  2009  Cuiabá     A
#
#                                         Seção (Nome)  Total
# 0  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      2
# 1  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     20
# 2  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      1
# 3  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      2
# 4  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     24

# %%
#df.rename(columns = {'Seção':'Setor', 'Seção (Nome)':'Nome do Setor'}, inplace = True)

# %%
empresas_Cuiaba = df.loc[(df['Local']=='Cuiabá')&(df['Tipo'] == 'N° de empresas')]
empresas_Cuiaba.head()
# Out:
#              Tipo   Ano   Local Seção  \
# 0  N° de empresas  2009  Cuiabá     A
# 1  N° de empresas  2009  Cuiabá     A
# 2  N° de empresas  2009  Cuiabá     A
# 3  N° de empresas  2009  Cuiabá     A
# 4  N° de empresas  2009  Cuiabá     A
#
#                                         Seção (Nome)  Total
# 0  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      2
# 1  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     20
# 2  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      1
# 3  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      2
# 4  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     24

# %%
#statisticas descritivas
empresas_Cuiaba.groupby('Ano').describe()
# Out:
#       Total
#       count       mean        std  min  25%  50%    75%    max
# Ano
# 2009  420.0  20.759524  48.122822  1.0  2.0  7.0  17.00  638.0
# 2010  419.0  22.064439  50.953944  1.0  3.0  7.0  19.00  676.0
# 2011  429.0  22.508159  50.867549  1.0  3.0  7.0  20.00  659.0
# 2012  430.0  23.430233  52.645523  1.0  3.0  7.0  21.75  689.0
# 2013  426.0  24.814554  54.799664  1.0  3.0  8.0  22.75  704.0
# 2014  428.0  25.404206  56.690934  1.0  3.0  8.0  22.00  716.0
# 2015  444.0  24.707207  57.171635  1.0  2.0  8.0  20.00  698.0
# 2016  433.0  25.498845  57.609281  1.0  3.0  8.0  22.00  659.0
# 2017  426.0  26.281690  59.190981  1.0  3.0  8.0  22.00  657.0
# 2018  432.0  26.472222  60.955913  1.0  3.0  8.0  23.00  700.0
# 2019  428.0  26.483645  59.553862  1.0  3.0  8.0  22.25  659.0
# 2020  434.0  25.440092  56.428150  1.0  3.0  8.0  22.75  611.0

# %%
funcionarios_Cuiaba = df.loc[(df['Local']=='Cuiabá')&(df['Tipo'] == 'N° de funcionários')]
funcionarios_Cuiaba.head()
# Out:
#                   Tipo   Ano   Local Seção  \
# 6   N° de funcionários  2009  Cuiabá     A
# 7   N° de funcionários  2009  Cuiabá     A
# 8   N° de funcionários  2009  Cuiabá     A
# 9   N° de funcionários  2009  Cuiabá     A
# 10  N° de funcionários  2009  Cuiabá     A
#
#                                          Seção (Nome)  Total
# 6   AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      3
# 7   AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...    704
# 8   AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      2
# 9   AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      3
# 10  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     46

# %%
funcionarios_Cuiaba.groupby('Ano').describe()
# Out:
#       Total
#       count        mean         std  min    25%   50%     75%     max
# Ano
# 2009  420.0  179.328571  463.724896  0.0   9.00  40.5  135.50  4325.0
# 2010  419.0  193.966587  499.425032  0.0  11.00  46.0  159.00  4687.0
# 2011  429.0  203.072261  495.400439  0.0  10.00  46.0  166.00  4295.0
# 2012  430.0  213.781395  526.313443  0.0  11.00  49.0  180.75  4719.0
# 2013  426.0  225.399061  555.079471  0.0  11.25  52.0  194.75  5080.0
# 2014  428.0  229.794393  564.349075  0.0  12.00  52.5  195.00  5511.0
# 2015  444.0  219.349099  574.296069  0.0   9.00  46.0  179.75  5536.0
# 2016  433.0  218.475751  558.780016  0.0  10.00  46.0  177.00  5174.0
# 2017  426.0  223.741784  557.361726  0.0  12.00  50.5  180.00  5317.0
# 2018  432.0  231.828704  612.528735  0.0  13.00  47.0  197.50  6104.0
# 2019  428.0  230.170561  591.808277  0.0  13.75  46.5  195.25  5789.0
# 2020  434.0  221.258065  575.527008  0.0  10.25  44.0  187.50  5659.0

# %%
#statisticas descritivas
empresas_Cuiaba.loc[(empresas_Cuiaba['Ano']==2009)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    7.0  2009.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2009.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  15.0  2009.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   41.0  2009.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   14.0  2009.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               5.0  2009.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2009.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  204.0  2009.0  0.0
# EDUCAÇÃO                                             10.0  2009.0  0.0
# INDÚSTRIAS DE TRANSFORMAÇÃO                           1.0  2009.0  NaN
# INFORMAÇÃO E COMUNICAÇÃO                             32.0  2009.0  0.0
# ...

# %%
empresas_Cuiaba.loc[(empresas_Cuiaba['Ano']==2020)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    7.0  2020.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2020.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  16.0  2020.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   46.0  2020.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   12.0  2020.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               6.0  2020.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2020.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  213.0  2020.0  0.0
# EDUCAÇÃO                                             11.0  2020.0  0.0
# INFORMAÇÃO E COMUNICAÇÃO                             34.0  2020.0  0.0
# OUTRAS ATIVIDADES DE SERVIÇOS                        19.0  2020.0  0.0
# ...

# %%
empresas_MT = df.loc[(df['Local']=='Mato Grosso')&(df['Tipo'] == 'N° de empresas')]
empresas_MT.head()
# Out:
#                Tipo   Ano        Local Seção  \
# 144  N° de empresas  2020  Mato Grosso     A
# 145  N° de empresas  2020  Mato Grosso     A
# 146  N° de empresas  2020  Mato Grosso     A
# 147  N° de empresas  2020  Mato Grosso     A
# 148  N° de empresas  2020  Mato Grosso     A
#
#                                           Seção (Nome)  Total
# 144  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     88
# 145  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     10
# 146  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...    264
# 147  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...    272
# 148  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...      7

# %%
funcionarios_MT = df.loc[(df['Local']=='Mato Grosso')&(df['Tipo'] == 'N° de funcionários')]
funcionarios_MT.head()
# Out:
#                    Tipo   Ano        Local Seção  \
# 240  N° de funcionários  2020  Mato Grosso     A
# 241  N° de funcionários  2020  Mato Grosso     A
# 242  N° de funcionários  2020  Mato Grosso     A
# 243  N° de funcionários  2020  Mato Grosso     A
# 244  N° de funcionários  2020  Mato Grosso     A
#
#                                           Seção (Nome)  Total
# 240  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...    397
# 241  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     33
# 242  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...    962
# 243  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...   3032
# 244  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...     15

# %%
#statisticas descritivas
empresas_MT.loc[(empresas_MT['Ano']==2009)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    9.0  2009.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2009.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  20.0  2009.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   46.0  2009.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   15.0  2009.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               5.0  2009.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2009.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  207.0  2009.0  0.0
# EDUCAÇÃO                                             13.0  2009.0  0.0
# INDÚSTRIAS DE TRANSFORMAÇÃO                           1.0  2009.0  NaN
# INFORMAÇÃO E COMUNICAÇÃO                             34.0  2009.0  0.0
# ...

# %%
empresas_MT.loc[(empresas_MT['Ano']==2020)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    9.0  2020.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             15.0  2020.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  21.0  2020.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   52.0  2020.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   13.0  2020.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               6.0  2020.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     31.0  2020.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  216.0  2020.0  0.0
# EDUCAÇÃO                                             12.0  2020.0  0.0
# INFORMAÇÃO E COMUNICAÇÃO                             38.0  2020.0  0.0
# OUTRAS ATIVIDADES DE SERVIÇOS                        23.0  2020.0  0.0
# ...

# %%
funcionarios_Cuiaba.loc[(funcionarios_Cuiaba['Ano']==2009)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    7.0  2009.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2009.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  15.0  2009.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   41.0  2009.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   14.0  2009.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               5.0  2009.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2009.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  204.0  2009.0  0.0
# EDUCAÇÃO                                             10.0  2009.0  0.0
# INDÚSTRIAS DE TRANSFORMAÇÃO                           1.0  2009.0  NaN
# INFORMAÇÃO E COMUNICAÇÃO                             32.0  2009.0  0.0
# ...

# %%
funcionarios_Cuiaba.loc[(funcionarios_Cuiaba['Ano']==2020)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    7.0  2020.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2020.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  16.0  2020.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   46.0  2020.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   12.0  2020.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               6.0  2020.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2020.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  213.0  2020.0  0.0
# EDUCAÇÃO                                             11.0  2020.0  0.0
# INFORMAÇÃO E COMUNICAÇÃO                             34.0  2020.0  0.0
# OUTRAS ATIVIDADES DE SERVIÇOS                        19.0  2020.0  0.0
# ...

# %%
funcionarios_MT.loc[(funcionarios_MT['Ano']==2009)].groupby('Seção (Nome)').describe()
# Out:
#                                                       Ano               \
#                                                     count    mean  std
# Seção (Nome)
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESC...    9.0  2009.0  0.0
# ALOJAMENTO E ALIMENTAÇÃO                             14.0  2009.0  0.0
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                  20.0  2009.0  0.0
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMEN...   46.0  2009.0  0.0
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS R...   15.0  2009.0  0.0
# ATIVIDADES IMOBILIÁRIAS                               5.0  2009.0  0.0
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS     30.0  2009.0  0.0
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E M...  207.0  2009.0  0.0
# EDUCAÇÃO                                             13.0  2009.0  0.0
# INDÚSTRIAS DE TRANSFORMAÇÃO                           1.0  2009.0  NaN
# INFORMAÇÃO E COMUNICAÇÃO                             34.0  2009.0  0.0
# ...

# %%
from google.colab import files

#empresas_Cuiaba.to_csv('empresasCuiaba.csv', encoding = 'utf-8-sig') 
#files.download('empresasCuiaba.csv')

# %%
#empresas_MT.to_csv('empresasMT.csv', encoding = 'utf-8-sig') 
#files.download('empresasMT.csv')

# %%
#funcionarios_Cuiaba.to_csv('funcionariosCuiaba.csv', encoding = 'utf-8-sig') 
#files.download('funcionariosCuiaba.csv')

# %%
#funcionarios_MT.to_csv('funcionariosMT.csv', encoding = 'utf-8-sig') 
#files.download('funcionariosMT.csv')

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# install.packages("esquisse")

# %%
# %%R
# #install.packages('RCurl')

# %%
# %%R
# library(tidyverse)
# library(ggplot2)
# library(esquisse)
# library(RCurl)
# Out:
# R[write to console]:
# Attaching package: ‘RCurl’
#
#
# R[write to console]: The following object is masked from ‘package:tidyr’:
#
#     complete

# %%
# %%R
# empresasCuiaba = read.csv("empresasCuiaba.csv")
# head(empresasCuiaba)
# Out:
#   X           Tipo  Ano  Local Seção
# 1 0 N° de empresas 2009 Cuiabá     A
# 2 1 N° de empresas 2009 Cuiabá     A
# 3 2 N° de empresas 2009 Cuiabá     A
# 4 3 N° de empresas 2009 Cuiabá     A
# 5 4 N° de empresas 2009 Cuiabá     A
# 6 5 N° de empresas 2009 Cuiabá     A
#                                                     Seção..Nome. Total
# 1 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA     2
# 2 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA    20
# 3 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA     1
# 4 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA     2
# 5 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA    24
# 6 AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQUICULTURA     1

# %%
# %%R
# esquisse::esquisser(empresasCuiaba)
# Out:
# R[write to console]: Loading required package: shiny
#
# R[write to console]:
# Listening on http://127.0.0.1:7662
#
# From cffi callback <function _processevents at 0x7fefa3657200>:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#     @ffi_proxy.callback(ffi_proxy._processevents_def,
# KeyboardInterrupt
# From cffi callback <function _processevents at 0x7fefa3657200>:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#     @ffi_proxy.callback(ffi_proxy._processevents_def,
# KeyboardInterrupt
# From cffi callback <function _processevents at 0x7fefa3657200>:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/rpy2/rinterface_lib/callbacks.py", line 274, in _processevents
#     @ffi_proxy.callback(ffi_proxy._processevents_def,
# KeyboardInterrupt

# %% [markdown]
# # New Section
